# %% [markdown]
# <font face="B Mitra" size=4>
# <div dir=rtl align=center>
# <br>
# <img src="https://aut.ac.ir/templates/tmpl_modern01/images/logo_fa.png" alt="Amirkabir University Logo" width="100">
# <br>
# <font size=6>
# <b>پروژه اول داده کاوی</b>
# <br>
# <b><font size=5> استاد درس: دکتر فاطمه شاکری</b>
# <br>
# <font size=4>
# <b>مهسا گودرزی - 9912043</b>
# <br>
# <hr>
# </div>
# </font>

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=5><font color='red'>
# توجه داشته باشید علاوه بر پیاده سازی خواسته شده، توضیحات لازم در محل تعریف شده را بیان کنید.
# </p>
# </font>
# </div>
# </font>

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <font size=6>
# <b> معرفی مجموعه داده </b>
# <br>
# <p align="justify">
# <font size=5>
# در این روزها، روابط کاری بیش از پیش به اعتماد متکی می‌شوند، و قراردادهای سخت گیرانه (که زمان کاری به دقت نظارت می‌شود) با قراردادهای انعطاف‌پذیرتر جایگزین می‌شوند که در آن کارمند به طور فردی مسئولیت حسابرسی زمان کاری را بر عهده دارد. این آزادی ممکن است منجر به غیبت بدون نظارت شود ، حتی اگر ساعات غیبت با دلایل معتبر قابل محاسبه باشد. این می‌تواند به طور قابل توجهی به روابط کاری سالم آسیب بزند. به علاوه، غیبت بدون نظارت می‌تواند تأثیر منفی بر بهره‌وری کاری داشته باشد
#
# هدف ما کشف الگوهای پنهان در داده‌هاست که ممکن است برای تمایز بین غیبت‌های واقعی از غیبت‌های تقلبی مفید باشند.
# همچنین با بررسی دلایل غیبت و تجدیدنظر در روند استخدامی در آینده ، میزان غیبت کاری را به حداقل رساند یا طرح هایی برای کاهش این ساعات درنظر گرفت.
# </p>
# </font>
# </div>
# </font>

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <font size=5>
# <b> بارگذاری کتابخانه های موردنیاز </b>
# <br>
# </div>
# </font>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <font size=5>
# <b> بارگذاری مجموعه داده </b>
# <br>
# </div>
# </font>

# %%
df = pd.read_excel(r"D:\Uni\Term8\DataMining\Tamrin\DataMining_Project1\Dataset.xls")
df.head()
# Out:
#    Employee_ID  Absence_Reason        Date  Transportation_Expense  \
# 0           11              26  07/07/2015                     289
# 1           36               0  14/07/2015                     118
# 2            3              23  15/07/2015                     179
# 3            7               7  16/07/2015                     279
# 4           11              23  23/07/2015                     289
#
#    Distance_to_Work  Employment_Service_Time  Employee_Age  \
# 0                36                       13            33
# 1                13                       18            50
# 2                51                       18            38
# 3                 5                       14            39
# 4                36                       13            33
#
#    Daily_Workload_Average  Target_Achievement_Rate  Disciplinary_Incident  \
# 0                  239554                       97                      0
# ...

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <font size=6>
# <b> پیش پردازش </b>
# <p align="justify">
# <font size=5>
# ابعاد داده را چاپ کنید.
# </p>
# </font>
# </div>
# </font>

# %%
df.shape
# Out:
# (700, 18)

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=5>
#  مقادیر گمشده را در مجموعه داده بررسی کنید.
# </p>
# </font>
# </div>
# </font>

# %%
df.isna().sum()
# Out:
# Employee_ID                0
# Absence_Reason             0
# Date                       0
# Transportation_Expense     0
# Distance_to_Work           0
# Employment_Service_Time    0
# Employee_Age               0
# Daily_Workload_Average     0
# Target_Achievement_Rate    0
# Disciplinary_Incident      0
# Education_Level            0
# Children                   0
# Social_Drinker_Status      0
# Social_Smoker_Status       0
#  Employee_Weight           0
# Employee_Height            0
# BMI                        0
# Absence_Duration_Hours     0
# dtype: int64

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=5>
# مقادیر آماری را به شکل زیر نشان دهید.
# </p>
# </font>
# </div>
# </font>

# %%
df.describe()
# Out:
#        Employee_ID  Absence_Reason  Transportation_Expense  Distance_to_Work  \
# count   700.000000      700.000000              700.000000        700.000000
# mean     17.951429       19.411429              222.347143         29.892857
# std      11.028144        8.356292               66.312960         14.804446
# min       1.000000        0.000000              118.000000          5.000000
# 25%       9.000000       13.000000              179.000000         16.000000
# 50%      18.000000       23.000000              225.000000         26.000000
# 75%      28.000000       27.000000              260.000000         50.000000
# max      36.000000       28.000000              388.000000         52.000000
#
#        Employment_Service_Time  Employee_Age  Daily_Workload_Average  \
# count               700.000000    700.000000              700.000000
# mean                 12.658571     36.417143           271801.774286
# ...

# %% [markdown]
# <div align=center>
# <br>
# <img src="https://drive.google.com/uc?id=1qM-jhi6ZXCHRBwgRShaYEV4ag4Pfd9gL" alt="Linear Algebra Cover Art" width="800">
# <br>
# </div>

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=5>
# رکوردهای تکراری را در مجموعه داده بررسی کنید و درصورت نیاز حذف کنید.
# </p>
# </font>
# </div>
# </font>

# %%
df[df.duplicated(keep=False)]
# Out:
#      Employee_ID  Absence_Reason        Date  Transportation_Expense  \
# 121           34              27  11/01/2016                     118
# 123           34              27  12/01/2016                     118
# 124           34              27  13/01/2016                     118
# 127           34              27  11/01/2016                     118
# 128           34              27  12/01/2016                     118
# 131           34              27  13/01/2016                     118
# 304            5              23  19/10/2016                     235
# 305            5              23  19/10/2016                     235
# 385            3              27  22/02/2017                     179
# 386            3              27  24/02/2017                     179
# 388            3              27  22/02/2017                     179
# 389            3              27  24/02/2017                     179
# 470           24              28  25/07/2017                     246
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (692, 18)

# %% [markdown]
# <font face="B Mitra">
#
# > Add blockquote
#
#
# <div dir=rtl>
# <p align="justify">
# <font size=5>
# با توجه به اینکه ویژگی Employee_ID ارزش اطلاعاتی ندارد، این ستون را حذف کنید.
# </p>
# </font>
# </div>
# </font>

# %%
df = df.drop(columns=['Employee_ID'])

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=5>
# ویژگی Date به شکل Series ذخیره شده است که دیتاتایپ مناسبی برای تحلیل سایر ویژگی ها بر اساس تاریخ نیست. ابتدا آن را به شکل Timestamp در آوردیم.
# <br>
# هر یک از مقادیر روزهفته ، ماه، سال را از آن استخراج کنید و در یک ستون جداگانه قرار دهید تا بتوانیم تحلیل هایی در ارتباط با تاریخ در ادامه انجام دهیم.
# <br>
# درنهایت ستون Date را حذف کنید.
# </p>
# </font>
# </div>
# </font>

# %%
type(df["Date"])
# Out:
# pandas.core.series.Series

# %%
# convert it to a date-time
df["Date"] = pd.to_datetime(df["Date"], format = '%d/%m/%Y')
# display the first date
df["Date"][0]
# Out:
# Timestamp('2015-07-07 00:00:00')

# %%
# extracting the Season out of the date
df['Year'] = df['Date'].dt.year

# %%
# extracting the Month out of the date
df['Month'] = df['Date'].dt.month

# %%
df['Month'] = df['Month'].map({
            1:"Jan",
            2:"Feb",
            3:"Mar",
            4:"Apr",
            5:"May",
            6:"Jun",
            7:"Jul",
            8:"Aug",
            9:"Sep",
            10:"Nov",
            11:"Oct",
            12:"Dec"})

# %%
# extracting the Weekday out of the date
df['Day_of_Week'] = df['Date'].dt.dayofweek

# %%
df['Day_of_Week'] = df['Day_of_Week'].map({
    0: 'Monday',
    1: 'Tuesday',
    2: 'Wednesday',
    3: 'Thursday',
    4: 'Friday',
    5: 'Saturday',
    6: 'Sunday'
})

# %%
df = df.drop(columns=['Date'])

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=5>
# دقت کنید که ویژگی های "Education_Level" , "Disciplinary_Incident" , "Social_Drinker_Status"و "Social_Smoker_Status" ویژگی های categorical هستند که به شکل عددی یا بولی ذخیره شده اند. بنابراین میتوانیم برای نمایش بهتر ویژگی ها به فرم categorical برگردانیم.
# </p>
# </font>
# </div>
# </font>

# %%
education_encoding = {1: "high_school", 2: "graduate", 3: "postgraduate", 4: "master_phd"}
yes_no_encoding = {0: "No", 1: "Yes"}

for column in ["Social_Drinker_Status", "Disciplinary_Incident", "Social_Smoker_Status"]:
    df[column] = df[column].replace(yes_no_encoding)
df["Education_Level"] = df["Education_Level"].replace(education_encoding)

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <font size=6>
# <b> EDA </b>
# <p align="justify">
# <font size=5>
# ما تلاش خواهیم کرد تا به سوالاتی مانند،  کدام عامل بیشترین غیبت را ایجاد می‌کند؟ آیا مصرف الکل یا دخانیات تأثیری بر دلایل دارد؟ آیا فاصله تا محل کار تأثیری بر علت غیبت دارد؟ و غیره، پاسخ دهیم. شروع با این نوع سوالات هنگام تحلیل داده اغلب مهم است ، زیرا این روش یک راه خوب برای به دست آوردن اطمینان و درک از داده‌هاست.
# </p>
# </font>
# <font size=5>
# <b>1.تشخیص دلایل غیبت </b>
# <br>
# 1.1. در ابتدا با استفاده از barplot و ویژگی Absence_Reason بررسی کنید سه دلیل پرتکرار غیبت در بین کارمندان چیست.
# </div>
# </font>

# %% [markdown]
# **Absence Reasons Among Employees**

# %%
absence_counts = df['Absence_Reason'].value_counts()
colors = ['orange', 'green', 'red', 'blue', 'purple', 'pink', 'brown']

plt.figure(figsize=(10, 6))
plt.bar(x=absence_counts.index, height=absence_counts.values, color=colors)
plt.xlabel('Absence Reason')
plt.ylabel('Counts')
plt.title('Absence Reasons Among Employees')
plt.xticks(np.arange(min(absence_counts.index), max(absence_counts.index)+1, 1), rotation=45)
plt.show()

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=4>
# <b> <font color='red'> توضیحات پاسخ:</font> </b> با توجه به نمودار فوق، متوجه می‌شویم که سه دلیل پرتکرار غیبت در بین کارمندان، به ترتیب دلایل 23 (مشاوره پزشکی)، 28 (مشاوره دندان) و 27 (فیزیوتراپی) است؛ زیرا طبق نمودار تعداد بیشتری را در بین دلایل به خود اختصاص داده‌اند.
# </p>
# </font>
# </div>
# </font>
# <hr>

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <font size=5>
# 2.1. توجه داشته باشید که فقط مقادیر 1 تا 21 کدهای موجود در جدول ICD را نشان می‌دهد. از آنجایی که تمام مقادیر موجود در ICD نشان دهنده یک نوع بیماری است،
# یک متغیر binary جدید تحت عنوان Disease تعریف کنید که بررسی کند دلیل غیبت  برای هر شخص در بازه ICD قرار دارد یا خیر.
# </div>
# </font>

# %%
def in_icd(val):
  return val in range(1, 22)

df['Disease'] = df['Absence_Reason'].apply(in_icd)

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=5>
# 3.1. سپس از barplot برای مقایسه تعداد افراد دو گروه بالا استفاده کنید.
# <br>
# تحلیل خود را از این نمودار بیان کنید.
# </p>
# </font>
# </div>
# </font>

# %% [markdown]
# **Count of ICD Matching Absence Reasons**

# %%
icd_status_counts = df['Disease'].value_counts()

plt.figure(figsize=(10, 6))
plt.bar(x=icd_status_counts.index.map(str), height=icd_status_counts.values, color=colors)
plt.title('Count of ICD Matching Absence Reasons')
plt.xlabel('ICD Status')
plt.ylabel('Count')
plt.yticks(np.arange(0, max(icd_status_counts.values) + 100, 50))
plt.show()

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=4>
# <b> <font color='red'> توضیحات پاسخ: </font></b>  طبق نمودار، دلایل غیبت کارکنان بیشتر مربوط به دلایل غیر از ICD می‌باشد که این تعداد نزدیک 450 تا است، در حالی که دلایل ICD کمتر از 250 تا می‌باشد.
#
# </p>
# </font>
# </div>
# </font>
# <hr>

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <font size=5>
# <b> 2. تحلیل مصرف کنندگان الکل و سیگار </b>
# <p align="justify">
# <font size=5>
# با تجزیه و تحلیل تأثیر مصرف الکل یا دخانیات بر غیبت کارکنان شروع کنیم. با توجه به اینکه سیگار کشیدن و مصرف مکرر الکل تأثیر منفی بر شرایط سلامتی دارند، انتظار داریم که برخی از بیماری‌ها در سیگاری‌ها و مصرف‌کنندگان الکل بیشتر از دیگران باشند.
# <br>
# 1.2. بررسی کنید چند درصد از غیبت‌ها، از گروه مصرف کننده الکل و چند درصد سیگاری هستند.
# </p>
# </font>
# </div>
# </font>

# %%
drinker_count = df['Social_Drinker_Status'].value_counts()['Yes']
smoker_count = df['Social_Smoker_Status'].value_counts()['Yes']

drinker_percentage = (drinker_count / len(df)) * 100
smoker_percentage = (smoker_count / len(df)) * 100

print(f"Percentage of Alcohol Consumers: {drinker_percentage:.2f}%")
print(f"Percentage of Smokers: {smoker_percentage:.2f}%")
# Out:
# Percentage of Alcohol Consumers: 57.51%
# Percentage of Smokers: 7.23%

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=5>
# 2.2. با توجه به درصد قابل توجه مصرف کنندگان الکل، با استفاده از barplot توزیع دلایل غیبت را در میان مصرف کنندگان الکل نشان دهید.
# همچنین  با تحلیل بصری این نمودار بررسی کنید که بیشترین اختلاف بین مصرف کنندگان الکل و سایرین در غیبت کاری، مرتبط با چه دلیلی است.
# </p>
# </font>
# </div>
# </font>

# %% [markdown]
# **Distribution of Absence Reasons Among Alcohol Consumers**

# %%
drinkers_data = df[df['Social_Drinker_Status'] == 'Yes']
drinkers_absence_reason_counts = drinkers_data['Absence_Reason'].value_counts()

plt.figure(figsize=(10, 6))
plt.bar(x=drinkers_absence_reason_counts.index, height=drinkers_absence_reason_counts.values, color=colors)
plt.title('Distribution of Absence Reasons Among Alcohol Consumers')
plt.xlabel('Absence Reason')
plt.ylabel('Count')
plt.xticks(np.arange(min(drinkers_absence_reason_counts.index), max(drinkers_absence_reason_counts.index)+1, 1), rotation=45)
plt.show()

# %% [markdown]
# **Distribution of Absence Reasons Among Non-Drinkers**

# %%
nondrinkers_data = df[df['Social_Drinker_Status'] == 'No']
nondrinkers_absence_reason_counts = nondrinkers_data['Absence_Reason'].value_counts()

plt.figure(figsize=(10, 6))
plt.bar(x=nondrinkers_absence_reason_counts.index, height=nondrinkers_absence_reason_counts.values, color=colors)
plt.title('Distribution of Absence Reasons Among Non-Drinkers')
plt.xlabel('Absence Reason')
plt.ylabel('Count')
plt.xticks(np.arange(min(nondrinkers_absence_reason_counts.index), max(nondrinkers_absence_reason_counts.index)+1, 1), rotation=45)
plt.show()

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=4>
# <b> <font color='red'> توضیحات پاسخ: </font></b>  با توجه به نمودارهای بالا، در بین مصرف‌کنندگان الکل، بیش‌ترین دلیل غیبت مربوط به دلیل 28 (مشاوره دندان) و در بین سایرین (Non-Drinkers) بیش‌ترین دلیل غیبت با اختلاف مربوط به دلیل 23 (مشاوره پزشکی) است. همچنین در بین مصرف کنندگان الکل، دلیل 23 رتبه دوم را از نظر بیش‌ترین علت غیبت را دارد (که اختلاف آن با دلیل اول یعنی دلیل 28 خیلی زیاد نیست) و در بین سایرین دلیل 28 دلیل پرشماری برای غیبت نمی‌باشد. (یعنی اختلاف نسبتا زیادی با دلیل اول یعنی دلیل 23 دارد)
#
# پس می‌توان نتیجه گرفت دلیل اصلی غیبت مصرف کنندگان الکل دلیل 28 (مشاوره دندان) است و این دلیل در بین سایرین آنچنان پر نقش نیست.
# </p>
# </font>
# </div>
# </font>
# <hr>

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=5>
# 3.2. برای تکمیل تحلیل مصرف کنندگان الکل و سیگار، با استفاده از violin plot توزیع تعداد ساعات غیبت را بین دو کلاس(مصرف کنندگان الکل و سایرین) بررسی کنید.
# <br>
# این تحلیل را به صورت مشابه برای افراد سیگار و سایرین انجام دهید.
# <br>
# همچنین توضیح دهید که violin plot برای تحلیل بصری در چه مواقعی مناسب است.
# </p>
# </font>
# </div>
# </font>

# %% [markdown]
# **Distribution of Absence Hours Among Alcohol Consumers and Non-consumers**

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 8))
sns.violinplot(x='Social_Drinker_Status', y='Absence_Duration_Hours', data=df, order=['Yes', 'No'])
plt.title('Distribution of Absence Hours Among Alcohol Consumers and Non-consumers')
plt.xlabel('Social Drinker Status')
plt.ylabel('Absence Duration (Hours)')
plt.yticks(np.arange(0, 160, 10))
plt.show()

# %% [markdown]
# **Distribution of Absence Hours Among Smokers and Others**

# %%
plt.figure(figsize=(10, 8))
sns.violinplot(x='Social_Smoker_Status', y='Absence_Duration_Hours', data=df, order=['Yes', 'No'])
plt.title('Distribution of Absence Hours Among Smokers and Others')
plt.xlabel('Social Smoker Status')
plt.ylabel('Absence Duration (Hours)')
plt.yticks(np.arange(0, 160, 10))
plt.show()

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=4>
# <b> <font color='red'> توضیحات پاسخ: </font></b>  با توجه به نمودار ویولنی اول، هر دو گروه مصرف‌کنندگان الکل و غیر مصرف‌کنندگان توزیع مشابهی از ساعات غیبت دارند و می‌توان نتیجه گرفت که مصرف الکل تأثیر قابل توجهی روی ساعات غیبت نمی‌گذارد. هر دو گروه دارای پهنای بالای مشابه در ساعات غیبت هستند، که نشان می‌دهد اکثر داده‌ها در حدود 0 الی 20 ساعت غیبت جمع شده‌اند با این تفاوت که پهنای گروه غیر مصرف‌کنندگان در این بازه کمی بیش‌تر است و همچنین در ساعات بالای غیبت، مصرف‌کنندگان الکل با اختلاف نچندان زیادی، سهم بیش‌تری را شامل می‌شوند و میانه گروه مصرف کنندگان الکل کمی بیش‌تر از میانه گروه سایرین است.
#
# با توجه به نمودار ویولنی دوم، مانند نتیجه نمودار قبلی، هر دو گروه افراد سیگاری و غیر سیگاری توزیع مشابهی از ساعات غیبت دارند و مصرف سیگار تأثیر قابل توجهی بر روی ساعات غیبت نمی‌گذارد. (این تأثیر، از تأثیر الکل بر روی ساعات غیبت نیز کم‌تر است)  هر دو گروه دارای پهنای بالای مشابه در ساعات غیبت هستند، که نشان می‌دهد اکثر داده‌ها در حدود 0 الی 20 ساعت غیبت جمع شده‌اند، با این تفاوت که پهنای گروه غیر سیگاری‌های در این بازه تا حدی بیش‌تر است و همچنین رکورد بیش‌ترین ساعت غیبت (حدود 130 ساعت) مربوط به گروه غیر سیگاری‌ها است و در بین زمان غیبت حدود 40 ساعت یا 60 تا 70 ساعت، سیگاری‌ها با اختلاف کمی سهم بیش‌تری را در این توزیع دارند. میانه دو گروه نیز تقریبا یکسان است.
#
# نمودار ویولنی یا Violon Plot برای زمانی که نیاز به نمایش توزیع کامل داده‌ها داریم مناسب است و نسبت به نمودار جعبه‌ای اطلاعات بیش‌تری را در اختیار ما قرار می‌دهد و توزیع فراوانی داده‌ها را به صورت بصری نشان می‌دهد که از این نظر برای نمایش‌های پیچیده نیز بسیار کاربردی است. همچنین زمانی که می‌خواهیم توزیع‌های داده‌ها را در چندین گروه به طور همزمان نشان دهیم و این توزیع‌های چندگانه را با هم مقایسه کنیم، نمودار ویولنی مناسب است. همچنین نمودار ویولنی می‌تواند تفاوت‌های دقیق و ریز بین توزیع داده‌ها را برای ما مشخص کند.
#
# </p>
# </font>
# </div>
# </font>
# <hr>

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <font size=5>
# <b> 3. فاکتورهای هزینه حمل و نقل و فاصله تا محل کار </b>
# <p align="justify">
# <font size=5>
# دو شاخص ممکن برای غیبت ممکن است فاصله بین خانه و محل کار و هزینه‌های حمل و نقل (ستون هزینه حمل و نقل) باشد. کارمندانی که باید مسافت بیشتری را طی کنند یا هزینه‌های حمل و نقل به محل کار آن‌ها بالاتر است، ممکن است به غیبت بیشتری دچار شوند. در این بخش، رابطه بین این متغیرها و زمان غیبت به ساعت را بررسی خواهیم کرد.
# <br>
#  از آنجا که ما اعتقاد نداریم که عوامل مذکور ممکن است نشان‌دهنده مشکلات بیماری باشند به معنای دیگر به طور ذاتی عامل بیماری نباشد، ما رابطه ممکن با ستون دلیل غیبت را در نظر نخواهیم گرفت و به بررسی رابطه آن با زمان غیبت بسنده میکنیم.
# <br>
# 1.3. با استفاده از joint plot رابطه بین فاصله محل اقامت تا کار و ساعات غیبت را نمایش دهید.
# <br>
# تحلیل بصری مشابهی برای ویژگی هزینه های حمل و نقل انجام دهید.
# <br> درمورد نمودار jointplot و موارد کاربرد آن توضیح دهید.
# </p>
# </font>
# </div>
# </font>

# %% [markdown]
# **Joint Plot of Distance to Work vs. Absence Duration Hours**

# %%
sns.jointplot(x='Distance_to_Work', y='Absence_Duration_Hours', data=df, kind='reg')
plt.xlabel('Distance to Work')
plt.ylabel('Absence Duration (Hours)')
plt.suptitle('Joint Plot of Distance to Work vs. Absence Duration Hours', y=1.05)
plt.show()

# %% [markdown]
# **Joint Plot of Transportation Expense vs. Absence Duration Hours**

# %%
sns.jointplot(x='Transportation_Expense', y='Absence_Duration_Hours', data=df, kind='reg')
plt.xlabel('Transportation Expense')
plt.ylabel('Absence Duration (Hours)')
plt.suptitle('Joint Plot of Transportation Expense vs. Absence Duration Hours', y=1.05)
plt.show()

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=4>
# <b> <font color='red'> توضیحات پاسخ: </font></b>  نمودار joint plot اول: در محور افقی، فاصله تا محل کار به کیلومتر نمایش داده شده است، که مقادیر آن از 0 تا حدود 50 کیلومتر متغیر است. در محور عمودی، تعداد ساعات غیبت نمایش داده شده است، که مقادیر آن از 0 تا 120 ساعت متغیر است. نقاط به صورت تقریبا یکنواخت در امتداد محور افقی پخش شده‌اند و همچنین بیشتر مقادیر غیبت در محدوده پایینی محور عمودی تمرکز دارند، یعنی اکثر ساعات غیبت به صورت کلی بالا نیست و غالبا چه کسانی که مسیر دورتری دارند و چه کسانی که مسیر نزدیک‌تری دارند، تقریبا ساعات غیبت مشابهی دارند. بیشترین تراکم داده در این نمودار به صورت کلی مربوط به کسانی می‌شود که فاصله حدودی 10 الی 30 کیلومتری یا فاصله حدودی 50 کیلومتری تا محل کار خود دارند و این افراد ساعت غیبت حدودی بین 0 تا 10 ساعت دارند. همچنین شیب این نمودار به میزان خیلی کمی منفی است و حتی می‌توان آن را تقریبا نموداری ثابت در نظر گرفت. در نتیجه نمی‌توان رابطه خاصی میان فاصله محل اقامت تا کار و ساعات غیبت مشاهده کرد و لزوما با افزایش این فاصله، ساعت غیبت افزایش نمی‌یابد و حتی ممکن است کمتر شود (با توجه به شیب کمی منفی نمودار).
#
# نمودار join plot دوم: تحلیل این نمودار نیز مشابه نمودار قبل است. در محور افقی، هزینه حمل و نقل از 0 تا 400 متغیر است و در محور عمودی، مقادیر ساعات غیبت از 0 تا 120 ساعت متغیر است. همچنین مانند نمودار قبلی نقاط به صورت تقریبا یکنواخت در امتداد محور افقی پخش شده‌اند و بیشتر مقادیر غیبت در محدوده پایینی محور عمودی تمرکز دارند و غالبا چه کسانی که هزینه بیشتری برای حمل و نقل می‌پردازند و چه کسانی که هزینه کمتری می‌پردازند، تقریبا ساعات غیبت مشابهی دارند. غالب افراد که هزینه‌های متفاوتی برای حمل و نقل می‌پردازند، ساعت غیبتی حدودی بین 0 تا 5 ساعت دارند. شیب این نمودار تقریبا صفر است و خط نموداری ثابت می‌باشد. در نتیجه نمی‌توان رابطه خاصی میان هزینه حمل و نقل و ساعات غیبت مشاهده کرد و لزوما با افزایش هزینه حمل و نقل، ساعت غیبت افزایش پیدا نمی‌کند.
#
# نمودار joint plot برای شناسایی رابطه بین دو متغیر به ما کمک می‌کند و نوع این رابطه چه خطی باشد چه غیر خطی، آن را کشف می‌کند. همچنین توزیع هر یک از متغیرهای ورودی را به صورت جداگانه بررسی می‌کند و در حاشیه نمودار نمایش می‌دهد. در واقع در مواردی که می‌خواهیم همزمان رابطه بین دو متغیر را بررسی کنیم و توزیع هر یک را به صورت جداگانه مورد تجزیه و تحلیل قرار دهیم، نمودار joint plot برای این امر مناسب است. این نمودار همچنین نقاط دور افتاده که با الگوی کلی همخوانی ندارند را به راحتی شناسایی می‌کند.
# </p>
# </font>
# </div>
# </font>
# <hr>

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=5>
# همانطور که مشاهده می‌شود، توزیع فواصل از محل اقامت تا محل کار و هزینه‌های حمل و نقل به نظر نزدیک به توزیع‌های نرمال می‌آید، در حالی که زمان غیبت به ساعت‌ها به شدت به سمت راست منحرف شده است. این موضوع باعث می‌شود مقایسه بین متغیرها دشوار باشد. یکی از راه‌حل‌های این مشکل، تبدیل داده‌ها به چیزی نزدیک به توزیع نرمال است. روشی موثر برای انجام این تبدیل، استفاده از تبدیل‌های Box-Cox یا Yeo-Johnson است که هر دو در کتابخانه scipy موجود است.
#
# 2.3. با توجه به اینکه ستون زمان غیبت شامل مقادیر صفر است از از تبدیل Yeo-Johnson استفاده کنید.
# <br>
# سپس هر دو نمودار بالا را مجددا رسم کنید و با تحلیل این نمودارها درمورد تاثیرگذاری این دو فاکتور بر روی زمان غیبت توضیح دهید.
# </p>
# </font>
# </div>
# </font>

# %%
from scipy.stats import yeojohnson

df['Normal_Absence_Duration_Hours'], lmbda = yeojohnson(df['Absence_Duration_Hours'])

# %% [markdown]
# **Joint Plot of Distance to Work vs. Normal Absence Duration Hours**

# %%
sns.jointplot(x='Distance_to_Work', y='Normal_Absence_Duration_Hours', data=df, kind='reg')
plt.xlabel('Distance to Work')
plt.ylabel('Absence Duration (Hours)')
plt.suptitle('Joint Plot of Distance to Work vs. Normal Absence Duration Hours', y=1.05)
plt.show()

# %% [markdown]
# **Joint Plot of Transportation Expense vs. Normal Absence Duration Hours**

# %%
sns.jointplot(x='Transportation_Expense', y='Normal_Absence_Duration_Hours', data=df, kind='reg')
plt.xlabel('Transportation Expense')
plt.ylabel('Absence Duration (Hours)')
plt.suptitle('Joint Plot of Transportation Expense vs. Normal Absence Duration Hours', y=1.05)
plt.show()

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=4>
# <b> <font color='red'> توضیحات پاسخ: </font></b>  نمودار اول: با توجه به نرمال‌سازی مقادیر ساعات غیبت، داده‌ها به جای آنکه در پایین محور عمودی متمرکز شوند، در طول این محور به صورت تقریبا یکنواخت پراکنده شده‌اند و به صورت تقریبا یکنواخت نیز در طول محور افقی پخش شده‌اند. اغلب داده‌ها در بین فاصله زمانی حدودی 0.5 تا 2 ساعت و فاصله حدودی 10 الی 50 کیلومتری متمرکز شده‌اند. همچنین شیب نمودار تقریبا صفر است و خط نموداری ثابت می‌باشد. پس در اینجا نیز به راحتی می‌توان فهمید که رابطه مستقیمی بین فاصله محل اقامت و کار با ساعات غیبت وجود ندارد و افزایش مسافت لزوما منجر به افزایش ساعت غیبت نمی‌شود و ممکن است کسی که مسافت بیش‌تری را باید طی کند  نسبت به کسی که مسافت کم‌تری را باید طی کند، ساعت غیبت یکسانی داشته باشد.
#
# نمودار دوم: در اینجا نیز با توجه به نرمال‌سازی مقادیر ساعات غیبت، داده‌ها به جای آنکه در پایین محور عمودی متمرکز شوند، در طول این محور به صورت تقریبا یکنواخت پراکنده شده‌اند و به صورت تقریبا یکنواخت نیز در طول محور افقی پخش شده‌اند. اغلب داده‌ها در بین فاصله زمانی حدودی 0.5 تا 2 ساعت و هزینه پرداختی حدودی 150 تا 350 متمرکز شده‌اند. همچنین شیب نمودار کمی مثبت است. پس در اینجا می‌توان فهمید تا حدی که میزان آن زیاد نیست، هزینه حمل و نقل می‌تواند بر ساعت غیبت تاثیر بگذراد و افرادی که بیش‌ترین هزینه را برای حمل و نقل می‌پردازند ممکن است نسبت به افرادی که کمترین هزینه را
#  می‌پردازند، حداکثر تا نیم ساعت غیبت بیش‌تری داشته باشند.
# </p>
# </font>
# </div>
# </font>
# <hr>

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <font size=5>
# <b> 4 . همبستگی </b>
# <p align="justify">
# <font size=5>
# با استفاده از heatmap همبستگی بین ویژگی ها را بررسی کنید.
# <br>
# درمورد نمودار heatmap و عملکرد آن به طور مختصر توضیح دهید.
# </p>
# </font>
# </div>
# </font>

# %%
# Remove the 'Normal_Absence_Duration_Hours' Column From the Dataset
df = df.drop(columns=['Normal_Absence_Duration_Hours'])

# New Encoding
new_education_encoding = {value: key for key, value in education_encoding.items()}
new_yes_no_encoding = {value: key for key, value in yes_no_encoding.items()}
for column in ["Social_Drinker_Status", "Disciplinary_Incident", "Social_Smoker_Status"]:
    df[column] = df[column].replace(new_yes_no_encoding)
df["Education_Level"] = df["Education_Level"].replace(new_education_encoding)

# %%
# Select Only the Numeric Columns From the Dataset
df_numeric = df.select_dtypes(include=np.number)

# Plot the Heatmap of The Correlation Matrix
sns.heatmap(df_numeric.corr(), linecolor='black', linewidth=0.5)
# Out:
# <Axes: >

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=4>
# <b> <font color='red'> توضیحات پاسخ: </font></b>  همان‌طور که مشاهده‌ می‌شود، این نمودار روابط بین متغیرهای عددی مختلف را به وسیله‌ی رنگ نشان می‌دهد و رنگ‌ها نشان‌دهنده‌ی میزان همبستگی هستند به طوری که رنگ‌های روشن‌تر نشان‌دهنده‌ی همبستگی قوی‌تر و رنگ‌های تیره‌تر نشان‌دهنده‌ی همبستگی ضعیف‌تر هستند. (از طریق نوار راهنمایی که در سمت راست نمودار آمده است میزان همبستگی هر دو متغیر را با یکدیگر متوجه می‌شویم) خانه‌های سفید بیش‌ترین همبستگی را دارند و خانه‌های سیاه کم‌ترین همبستگی را دارند. برای مثال؛ همبستگی هر ویژگی با خودش بیش‌ترین است که این مورد واضح می‌باشد. برای مثالی دیگر، ویژگی BMI هر فرد با میزان وزن او همبستگی زیادی دارد (هر چقدر وزن بیش‌تر، مقدار BMI نیز بیش‌تر). برای مثالی دیگر، ویژگی وضعیت مصرف الکل هر فرد با میزان تحصیلات او همبستگی خیلی کمی دارد، در واقع هر چقدر میزان تحصیلات فرد بیش‌تر باشد احتمال مصرف الکل او کمتر است.
#
# نمودار heatmap یک نمودار دوبعدی است که از رنگ‌ها برای نمایش همبستگی میان داده‌های عددی استفاده می‌کند. این نمودار برای نشان دادن روابط بین دو متغیر استفاده می‌شود، که یکی بر روی هر محور نمودار قرار می‌گیرد. با مشاهده تغییر رنگ‌ها در سراسر هر محور، می‌توانیم ببینیم که آیا همبستگی‌ای میان هر دو متغیر وجود دارد یا خیر. نمودار heatmap برای نمایش الگوها، روابط و تفاوت‌های میان داده‌های مختلف بسیار مفید است. این نمودار معمولا برای نمایش ماتریس‌های داده، همبستگی بین متغیرها، تغییرات زمانی و غیره استفاده می‌شود. به کمک heatmap می‌توان الگوها و تغییرات مهم را در داده‌ها به سرعت تشخیص داد و تحلیل کرد و امکان مقایسه، تشخیص الگوها و استخراج اطلاعات مهم فراهم می‌شود.
# </p>
# </font>
# </div>
# </font>
# <hr>

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <font size=5>
# <b> 5 . سن </b>
# <p align="justify">
# <font size=5>
# سن نیز ممکن است بر غیبت کارمندان تاثیر بگذارد.کارمندان سنین بالاتر ممکن است نیاز به درمان‌های پزشکی مکرر داشته باشند.
# <br>
# 1.5. با استفاده از نمودار displot درمورد توزیع سن  کارمندان و چولگی نمودار بحث کنید.
# </p>
# </font>
# </div>
# </font>

# %%
sns.displot(df['Employee_Age'], kde=True)
skewness = df['Employee_Age'].skew()
plt.title(f'Distribution of Employee Age with Skewness: {skewness:.2f}')
plt.xlabel('Employee Age')
plt.show()

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=4>
# <b> <font color='red'> توضیحات پاسخ: </font></b>  این نمودار که چولگی آن 0.65 است، چولگی مثبت و متوسطی دارد؛ به این معنا که توزیع سنی کارمندان تمایل به سمت مقادیر پایین‌تر دارد. بیش‌ترین تعداد کارمندان (بیش‌ترین تراکم) در حدود سن 35 تا 40 سالگی قرار دارد و کمترین تعداد کارمندان (کمترین تراکم) مربوط به سن 50 سالگی به بعد است.
# </p>
# </font>
# </div>
# </font>
# <hr>

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=5>
# 2.5. جهت بررسی تاثیر سن در بیماری ها، با استفاده از violin plot توزیع سن بین دو گروه افراد براساس  ویژگی "Disease"  در قسمت 1 را نمایش دهید و تحلیل خود را از این نمودار بیان کنید.
# </p>
# </font>
# </div>
# </font>

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='Disease', y='Employee_Age', data=df)
plt.title('Distribution of Age Among Diseas')
plt.xlabel('Diseas')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=4>
# <b> <font color='red'> توضیحات پاسخ: </font></b>  با توجه به این نمودار، توزیع سن در بین کسانی که دچار بیماری هستند و کسانی که بیمار نیستند، تقریبا مشابه است و اختلاف بسیار زیاد و فاحشی وجود ندارد. میانه هر دو گروه تقریبا یکسان است. همچنین در هر دو گروه، بیش‌ترین توزیع سنی مربوط به سن 35 تا 40 سالگی است که البته توزیع آن در بین افرادی که دچار بیماری نیستند، بیش‌تر می‌باشد. همچنین در بازه سنی 30 تا 35 سالگی، تعداد افرادی که دچار بیماری هستند کمی بیش‌تر از افراد سالم است. در میان افرادی که بیش‌ترین سن را دارند (یعنی افراد بالای 55 سال) تعداد کسانی که به بیماری دچار هستند‌، بیش‌تر از افراد بدون بیماری است.
# </p>
# </font>
# </div>
# </font>
# <hr>

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=5>
# 3.5. با استفاده از barplot در بازه های ده ساله بررسی کنید آیا افراد با سنین بالاتر ساعات بیشتری غیبت میکنند؟
# </p>
# </font>
# </div>
# </font>

# %%
age_range = df['Employee_Age'].unique()
age_range
# Out:
# array([33, 50, 38, 39, 28, 36, 34, 37, 41, 47, 29, 48, 32, 27, 43, 40, 31,
#        30, 49, 58, 46], dtype=int64)

# %%
df['Age_Group'] = pd.cut(df['Employee_Age'], bins=np.arange(20,70, 10), right=False)
grouped = df.groupby('Age_Group')['Absence_Duration_Hours'].mean()

grouped.plot(kind='bar')
plt.title('Average Employee Absenteeism Hours Over Ten-Year Periods')
plt.xlabel('Age Group')
plt.ylabel('Absence Duration (Hours)')
plt.show()

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=4>
# <b> <font color='red'> توضیحات پاسخ: </font></b> همان‌طور که در نمودار هم دیده می‌شود، کمترین میانگین ساعات غیبت در بین گروه سنی 20 تا 30 سال، و بیش‌ترین میانگین ساعات غیبت در بین گروه سنی 50 تا 60 سال است که اختلاف آن از میانگین ساعات غیبت بقیه گروه‌های سنی بسیار بیش‌تر است. پس به صورت کلی می‌توان گفت افراد با سنین بالاتر، نسبت به افراد با سنین کم‌تر، ساعات بیش‌تری را غیبت می‌کنند. البته همان‌طور که ذکر شد، این گزاره به صورت کلی نتیجه گرفته شده است و لزوما هر فردی که سن بالاتری دارد، نسبت به فرد سن پایین‌تر خود ساعت غیبت بیش‌تری ندارد. برای مثال با اختلاف بسیار کمی، میانگین ساعات غیبت گروه سنی 40 تا 50 سال از گروه سنی 30 تا 40 سال کم‌تر است ولی این اختلاف به حدی نیست که گزاره‌ی کلی گفته شده را نقض کند.
# </p>
# </font>
# </div>
# </font>
# <hr>

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <font size=5>
# <b> 6. بررسی سایر فاکتورها </b>
# <p align="justify">
# <font size=5>
# 1.6. با استفاده از نمودارها و روش های مناسب تاثیرگذاری این عوامل را در مرخصی کارمندان بررسی کنید.
# <br>
#
# 1.   تحصیلات:
# کارمندان با مدارک تحصیلی بالاتر که مسئولیت‌های بالاتری را بر عهده دارند، ممکن است کمتر به مشکلاتی از این دست دچار شوند.
#
#
# </p>
# </font>
# </div>
# </font>

# %%
# Encoding
education_encoding = {1: "high_school", 2: "graduate", 3: "postgraduate", 4: "master_phd"}

df["Education_Level"] = df["Education_Level"].replace(education_encoding)

# %% [markdown]
# **Analyzing Absence Dependency of Number of Education Level**

# %%
Education_Level_order = ['high_school', 'graduate', 'postgraduate', 'master_phd']
Education_Level_count = df[['Education_Level','Absence_Duration_Hours']].groupby('Education_Level').mean()
plt.figure(figsize=(10, 6))
sns.barplot(x='Education_Level', y='Absence_Duration_Hours', data=Education_Level_count, order=Education_Level_order)
plt.title('Analyzing Absence Dependency of Number of Education Level')
plt.xlabel('Education Level')
plt.ylabel('Absence Duration (Hours)')
plt.show()

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=4>
# <b> <font color='red'> توضیحات پاسخ: </font></b>
# تحصیلات کارمندان: کارمندانی که تحصیلات بالاتری دارند، میانگین ساعتی کمتری را غیبت می‌کنند؛ در واقع بیش‌ترین میانگین ساعتی غیبت مربوط به کارمندان با مدرک تحصیلی دبیرستان و کم‌ترین میانگین ساعتی غیبت مربوط به کارمندان با مدرک تحصیلی ارشد و دکتری است.
# </p>
# </font>
# </div>
# </font>
# <hr>

# %% [markdown]
# **Distribution of Absence Reason Among Education Levels**

# %%
plt.figure(figsize=(10, 8))
sns.violinplot(x='Education_Level', y='Absence_Reason', data=df, order=Education_Level_order)
plt.title('Distribution of Absence Reason Among Education Levels')
plt.xlabel('Education Level')
plt.ylabel('Absence Reason')
plt.yticks(np.arange(0, 30, 1), rotation=45, size=7)
plt.show()

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=4>
# <b> <font color='red'> توضیحات پاسخ: </font></b>
# همچنین طبق نمودار توزیع دلایل غیبت بر اساس مدرک تحصیلی، می‌توان فهمید هر گروه مدرک تحصیلی به چه دلیلی بیش‌ترین غیبت را دارند. برای مثال آن‌هایی که مدرک تحصیلی دبیرستان را دارند، بیش‌تر به خاطر دلایل 22 تا تا 28 غیبت می‌کنند و میانه گروه آن‌ها تقریبا به دلیل 23 برمی‌گردد. همین استدلال را می‌توان برای گروه‌های دیگر نیز به کار برد.
# </p>
# </font>
# </div>
# </font>

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=5>
# 2. بررسی ساعت‌های غیبت بر اساس روز هفته و ماه سال
# </font>
# </div>
# </font>

# %% [markdown]
# **Analyzing Absence Dependency of Day of Week**

# %%
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_count_mean = df[['Day_of_Week','Absence_Duration_Hours']].groupby('Day_of_Week').mean()
plt.figure(figsize=(10, 6))
sns.barplot(x='Day_of_Week', y='Absence_Duration_Hours', data=day_count_mean, order=day_order)
plt.title('Analyzing Hours of Absence Dependency of Day of Week')
plt.xlabel('Day of Week')
plt.ylabel('Absence Duration (Hours)')
plt.show()

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=4>
# <b> <font color='red'> توضیحات پاسخ: </font></b>
# روز هفته: طبق نمودار، کارمندان در روز دوشنبه که اولین روز کاری هفته محسوب می‌شود، بیش‌ترین میانگین ساعت غیبت را دارند و همچنین در روز یکشنبه که روز تعطیل است، کم‌ترین میانگین ساعت غیبت را دارند.
# </p>
# </font>
# </div>
# </font>
# <hr>

# %% [markdown]
# **Analyzing Absence Dependency of Month of Year**

# %%
month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
month_count_mean = df[['Month','Absence_Duration_Hours']].groupby('Month').mean()
plt.figure(figsize=(10, 6))
sns.barplot(x='Month', y='Absence_Duration_Hours', data=month_count_mean, order=month_order)
plt.title('Analyzing Hours of Absence Dependency of Month of Year')
plt.xlabel('Month')
plt.ylabel('Absence Duration (Hours)')
plt.show()

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=4>
# <b> <font color='red'> توضیحات پاسخ: </font></b>
# ماه: طبق نمودار کارمندان در ماه آوریل (April) بیش‌ترین میانگین غیبت ساعتی را در بین ماه‌های سال دارند و کم‌ترین میانگین غیبت ساعتی مربوط به ماه فوریه (February) می‌شود.
# </p>
# </font>
# </div>
# </font>
# <hr>

# %% [markdown]
# **Analyzing Absence Dependency of Year**

# %%
year_mean_count = df[['Year','Absence_Duration_Hours']].groupby('Year').mean().sort_values('Year')
plt.figure(figsize=(10, 6))
sns.barplot(x='Year', y='Absence_Duration_Hours', data=year_mean_count)
plt.title('Analyzing Hours of Absence Dependency of Year')
plt.xlabel('Year')
plt.ylabel('Absence Duration (Hours)')
plt.show()

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=4>
# <b> <font color='red'> توضیحات پاسخ: </font></b>
# سال: طبق نمودار، بیش‌ترین میانگین ساعتی غیبت مربوط به سال 2016 و کم‌ترین میانگین ساعتی غیبت مربوط به سال 2017 است. البته میزان اختلاف میانگین ساعتی غیبت بین سال‌های مختلف بسیار کم است و همچنین نمی‌توان گفت که با گذشت سال‌های بیش‌ترین میانگین ساعتی غیبت کم‌تر یا بیش‌تر شده است.
# </p>
# </font>
# </div>
# </font>
# <hr>

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=5>
# 3. تعداد فرزندان
# </font>
# </div>
# </font>

# %% [markdown]
# **Analyzing Absence Dependency of Number of Children**

# %%
child_count = df[['Children','Absence_Duration_Hours']].groupby('Children').mean().sort_values('Children')
plt.figure(figsize=(10, 6))
sns.barplot(x='Children', y='Absence_Duration_Hours', data=child_count)
plt.title('Analyzing Absence Dependency of Number of Children')
plt.xlabel('Children')
plt.ylabel('Absence Duration (Hours)')
plt.show()

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=4>
# <b> <font color='red'> توضیحات پاسخ: </font></b>
# تعداد فرزندان: طبق نمودار، بیش‌ترین میانگین ساعتی غیبت مربوط به کسانی است که دو فرزند دارند، و کم‌ترین میانگین ساعتی غیبت مربوط به کسانی است که هیچ فرزندی ندارند. در واقع فرزند داشتن نسبت به فرزند نداشتن می‌تواند منجر به میزان غیبت بیش‌تر شود اما لزوما تعداد فرزندان بیش‌تر، میانگین ساعتی غیبت را بالا نمی‌برد.
# </p>
# </font>
# </div>
# </font>
# <hr>

# %% [markdown]
# **Distribution of Absence Reasons Among Number of Children**

# %%
plt.figure(figsize=(10, 8))
sns.violinplot(x='Children', y='Absence_Reason', data=df, order=[0, 1, 2, 3, 4])
plt.title('Distribution of Absence Reasons Among Number of Children')
plt.xlabel('Children')
plt.ylabel('Absence Reason')
plt.yticks(np.arange(0, 30, 1), rotation=45, size=7)
plt.show()

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=4>
# <b> <font color='red'> توضیحات پاسخ: </font></b>
# همان‌طور که اشاره کردیم، لزوما تعداد فرزندان بیش‌تر، میانگین ساعتی غیبت را بالا نمی‌برد. برای مثال کسانی که 3 یا 4 فرزند دارند، نسبت به کسانی که 2 فرزند دارند، میانگین ساعتی غیبت کم‌تری دارند. همچنین با توجه به نمودار توزیع دلایل غیبت بر اساس تعداد فرزند، می‌توان دید کسانی که فرزندی ندارند یا تعداد فرزندانشان کم است، در بین دلایل، بیش‌تر به خاطر دلایل 21 تا 28 غیبت می‌کنند و کسانی که فرزند بیش‌تری دارند، دلایل غیبتشان توزیع یکنواخت‌تری دارد. همچنین با توجه به نمودار ویولنی هر گروه، می‌توان این تحلیل را دقیق‌تر کرد و متوجه شد که بیش‌ترین توزیع دلایل غیبت در بین کدام دلایل است، میانه به چه دلیلی نزدیک‌تر است و کم‌ترین دلیل توزیع شده چه دلیلی است. برای مثال میانه گروهی که هیچ فرزندی ندارند، به دلیل 23 نزدیک‌تر است.
#
# </p>
# </font>
# </div>
# </font>
# <hr>
